# %% [markdown]
# # 단어 세기 Word Counting

# %% [markdown]
# ## 문제
#
# 텍스트가 입력으로 주어질 때, 단어의 개수를 세는 프로그램을 작성한다.
#
# "문자 세기"와 "단어 세기"는 프로그래밍 입문에 성공했는지를 가늠하는 문제라고 할 수 있습니다.

# %% [markdown]
# ## 출력
#
#
# 구분자(Separator)는 마침표 '.', 쉼표 ',', 공백 ' ' 이다.
#
# 가장 많이 나온 순서대로 단어 10개와 그 단어의 빈도를 출력한다.
#
# 빈도가 같은 단어들 사이의 순서는 무시한다.
#
#
# in 12
# the 10
# Bolikango 5
# a 4
# of 4
# and 3
# to 3
# his 3
# became 2
# government 2

# %%
with open('text.txt','r') as f:
    text=f.read()
    #print(text)

# %%
word=text.replace(',',' ').replace('.',' ').split()
word_list=list(set(word))
word_count=[]
for word1 in word_list:
    word_count.append((word.count(word1),word1)) 
n=0

for result in sorted(word_count, reverse=True):
    n += 1
    print(result[1],':',result[0])
    if n == 10:
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-439816352af6> in <module>
#       6 n=0
#       7
# ----> 8 for result in sorted(word_count[0], reverse=True):
#       9     n += 1
#      10     print(result[1],':',result[0])
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
word_count
# Out:
# [(1, 'minister'),
#  (2, 'Minister'),
#  (1, 'partial'),
#  (1, 'but'),
#  (2, 'as'),
#  (1, 'country'),
#  (1, 'again'),
#  (1, 'warring'),
#  (2, 'Congo'),
#  (4, 'of'),
#  (1, 'The'),
#  (1, '1961'),
#  (5, 'Bolikango'),
#  (1, 'parliamentary'),
#  (1, '1970'),
#  (1, 'Parliament'),
#  (2, 'before'),
#  (1, 'took'),
#  (3, 'and'),
#  (1, 'created'),
#  (1, 'several'),
#  (2, 'served'),
#  (1, 'died'),
#  (1, 'Jean'),
#  (1, 'returning'),
#  (1, 'years'),
#  (1, 'by'),
#  (1, 'reestablished'),
#  (1, 'grandson'),
#  (2, 'He'),
#  (1, 'political'),
#  (2, 'bureau'),
#  (1, 'awarded'),
#  (1, '1965'),
#  (1, 'posthumously'),
#  (1, 'for'),
#  (1, 'dismissed'),
#  (1, 'power'),
#  (1, 'later'),
#  (1, 'new'),
#  (10, 'the'),
#  (1, 'governments'),
#  (1, 'mediated'),
#  (1, '1975'),
#  (1, 'Revolution'),
#  (1, 'Foundation'),
#  (1, 'once'),
#  (2, 'government'),
#  (2, 'Mobutu'),
#  (1, 'promote'),
#  (1, 'After'),
#  (1, 'one'),
#  (1, 'progress'),
#  (1, 'first'),
#  (2, 'him'),
#  (2, 'was'),
#  (1, 'domestic'),
#  (1, 'President'),
#  (1, 'Populaire'),
#  (1, 'crisis'),
#  (1, 'As'),
#  (4, 'a'),
#  (1, 'Joseph-Desire'),
#  (1, 'dislodged'),
#  (2, 'Prime'),
#  (2, 'Deputy'),
#  (1, 'soon'),
#  (2, 'left'),
#  (1, '1962'),
#  (1, 'public'),
#  (1, '2005'),
#  (1, 'long'),
#  (1, 'medal'),
#  (3, 'to'),
#  (1, 'between'),
#  (12, 'in'),
#  (3, 'his'),
#  (1, 'seven'),
#  (1, 'briefly'),
#  (1, 'His'),
#  (2, 'became'),
#  (1, 'administrations'),
#  (1, 'de'),
#  (1, 'succeeded'),
#  (1, 'opposition'),
#  (1, 'state'),
#  (1, 'factions'),
#  (1, 'different'),
#  (1, 'embroiled'),
#  (1, 'Mouvement'),
#  (1, 'memory'),
#  (1, 'social'),
#  (1, 'stability'),
#  (1, 'career'),
#  (1, 'service'),
#  (1, 'appointed'),
#  (1, 'la'),
#  (1, 'la'),
#  (1, 'la')]

# %%
sorted(word_count, reverse=True)
# Out:
# [(12, 'in'),
#  (12, 'in'),
#  (12, 'in'),
#  (12, 'in'),
#  (12, 'in'),
#  (12, 'in'),
#  (12, 'in'),
#  (12, 'in'),
#  (12, 'in'),
#  (12, 'in'),
#  (12, 'in'),
#  (12, 'in'),
#  (10, 'the'),
#  (10, 'the'),
#  (10, 'the'),
#  (10, 'the'),
#  (10, 'the'),
#  (10, 'the'),
#  (10, 'the'),
#  (10, 'the'),
#  (10, 'the'),
#  (10, 'the'),
#  (5, 'Bolikango'),
#  (5, 'Bolikango'),
#  (5, 'Bolikango'),
#  (5, 'Bolikango'),
#  (5, 'Bolikango'),
#  (4, 'of'),
#  (4, 'of'),
#  (4, 'of'),
#  (4, 'of'),
#  (4, 'a'),
#  (4, 'a'),
#  (4, 'a'),
#  (4, 'a'),
#  (3, 'to'),
#  (3, 'to'),
#  (3, 'to'),
#  (3, 'his'),
#  (3, 'his'),
#  (3, 'his'),
#  (3, 'and'),
#  (3, 'and'),
#  (3, 'and'),
#  (2, 'was'),
#  (2, 'was'),
#  (2, 'served'),
#  (2, 'served'),
#  (2, 'left'),
#  (2, 'left'),
#  (2, 'him'),
#  (2, 'him'),
#  (2, 'government'),
#  (2, 'government'),
#  (2, 'bureau'),
#  (2, 'bureau'),
#  (2, 'before'),
#  (2, 'before'),
#  (2, 'became'),
#  (2, 'became'),
#  (2, 'as'),
#  (2, 'as'),
#  (2, 'Prime'),
#  (2, 'Prime'),
#  (2, 'Mobutu'),
#  (2, 'Mobutu'),
#  (2, 'Minister'),
#  (2, 'Minister'),
#  (2, 'He'),
#  (2, 'He'),
#  (2, 'Deputy'),
#  (2, 'Deputy'),
#  (2, 'Congo'),
#  (2, 'Congo'),
#  (1, 'years'),
#  (1, 'warring'),
#  (1, 'took'),
#  (1, 'succeeded'),
#  (1, 'state'),
#  (1, 'stability'),
#  (1, 'soon'),
#  (1, 'social'),
#  (1, 'several'),
#  (1, 'seven'),
#  (1, 'service'),
#  (1, 'returning'),
#  (1, 'reestablished'),
#  (1, 'public'),
#  (1, 'promote'),
#  (1, 'progress'),
#  (1, 'power'),
#  (1, 'posthumously'),
#  (1, 'political'),
#  (1, 'partial'),
#  (1, 'parliamentary'),
#  (1, 'opposition'),
#  (1, 'one'),
#  (1, 'once'),
#  (1, 'new'),
#  (1, 'minister'),
#  (1, 'memory'),
#  (1, 'mediated'),
#  (1, 'medal'),
#  (1, 'long'),
#  (1, 'later'),
#  (1, 'la'),
#  (1, 'grandson'),
#  (1, 'governments'),
#  (1, 'for'),
#  (1, 'first'),
#  (1, 'factions'),
#  (1, 'embroiled'),
#  (1, 'domestic'),
#  (1, 'dismissed'),
#  (1, 'dislodged'),
#  (1, 'different'),
#  (1, 'died'),
#  (1, 'de'),
#  (1, 'crisis'),
#  (1, 'created'),
#  (1, 'country'),
#  (1, 'career'),
#  (1, 'by'),
#  (1, 'but'),
#  (1, 'briefly'),
#  (1, 'between'),
#  (1, 'awarded'),
#  (1, 'appointed'),
#  (1, 'again'),
#  (1, 'administrations'),
#  (1, 'The'),
#  (1, 'Revolution'),
#  (1, 'President'),
#  (1, 'Populaire'),
#  (1, 'Parliament'),
#  (1, 'Mouvement'),
#  (1, 'Joseph-Desire'),
#  (1, 'Jean'),
#  (1, 'His'),
#  (1, 'Foundation'),
#  (1, 'As'),
#  (1, 'After'),
#  (1, '2005'),
#  (1, '1975'),
#  (1, '1970'),
#  (1, '1965'),
#  (1, '1962'),
#  (1, '1961')]

# %%
with open('text.txt', 'r') as f:
    text = f.read()
word_list = text.replace(',', ' ').replace('.', ' ').split()
word_list_no_duplicate = list(set(word_list))
word_count = []
for word in word_list_no_duplicate:
    word_count.append((word_list.count(word), word))
n = 0
for result in sorted(word_count, reverse=True):
    n += 1
    print(result[1], ':', result[0])
    if n == 10:
        break
# Out:
# in : 12
# the : 10
# Bolikango : 5
# of : 4
# a : 4
# to : 3
# his : 3
# and : 3
# was : 2
# served : 2

# %%
sorted(word_count, reverse=True)
# Out:
# [(12, 'in'),
#  (10, 'the'),
#  (5, 'Bolikango'),
#  (4, 'of'),
#  (4, 'a'),
#  (3, 'to'),
#  (3, 'his'),
#  (3, 'and'),
#  (2, 'was'),
#  (2, 'served'),
#  (2, 'left'),
#  (2, 'him'),
#  (2, 'government'),
#  (2, 'bureau'),
#  (2, 'before'),
#  (2, 'became'),
#  (2, 'as'),
#  (2, 'Prime'),
#  (2, 'Mobutu'),
#  (2, 'Minister'),
#  (2, 'He'),
#  (2, 'Deputy'),
#  (2, 'Congo'),
#  (1, 'years'),
#  (1, 'warring'),
#  (1, 'took'),
#  (1, 'succeeded'),
#  (1, 'state'),
#  (1, 'stability'),
#  (1, 'soon'),
#  (1, 'social'),
#  (1, 'several'),
#  (1, 'seven'),
#  (1, 'service'),
#  (1, 'returning'),
#  (1, 'reestablished'),
#  (1, 'public'),
#  (1, 'promote'),
#  (1, 'progress'),
#  (1, 'power'),
#  (1, 'posthumously'),
#  (1, 'political'),
#  (1, 'partial'),
#  (1, 'parliamentary'),
#  (1, 'opposition'),
#  (1, 'one'),
#  (1, 'once'),
#  (1, 'new'),
#  (1, 'minister'),
#  (1, 'memory'),
#  (1, 'mediated'),
#  (1, 'medal'),
#  (1, 'long'),
#  (1, 'later'),
#  (1, 'la'),
#  (1, 'grandson'),
#  (1, 'governments'),
#  (1, 'for'),
#  (1, 'first'),
#  (1, 'factions'),
#  (1, 'embroiled'),
#  (1, 'domestic'),
#  (1, 'dismissed'),
#  (1, 'dislodged'),
#  (1, 'different'),
#  (1, 'died'),
#  (1, 'de'),
#  (1, 'crisis'),
#  (1, 'created'),
#  (1, 'country'),
#  (1, 'career'),
#  (1, 'by'),
#  (1, 'but'),
#  (1, 'briefly'),
#  (1, 'between'),
#  (1, 'awarded'),
#  (1, 'appointed'),
#  (1, 'again'),
#  (1, 'administrations'),
#  (1, 'The'),
#  (1, 'Revolution'),
#  (1, 'President'),
#  (1, 'Populaire'),
#  (1, 'Parliament'),
#  (1, 'Mouvement'),
#  (1, 'Joseph-Desire'),
#  (1, 'Jean'),
#  (1, 'His'),
#  (1, 'Foundation'),
#  (1, 'As'),
#  (1, 'After'),
#  (1, '2005'),
#  (1, '1975'),
#  (1, '1970'),
#  (1, '1965'),
#  (1, '1962'),
#  (1, '1961')]
